# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
dir_path = 'C:/Users/khanh/Downloads/src_cv/img/01/1.jpg'
im = Image.open(dir_path)
#display(im)
plt.imshow(im)

# %%
x = [1,2,3,4,5]
y = [10,16,20,30,25]
plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [10,16,20,30,25]
plt.plot(x,y,color="red") #color
plt.title('Table with red') #title
plt.axis('off') #turn off
plt.show()

# %%
im = Image.open(dir_path)
x = [100,100,400,400]
y = [200,300,200,300]

plt.imshow(im)
plt.plot(x,y,'r*')
plt.plot(x,y,'ys:')
plt.show()
