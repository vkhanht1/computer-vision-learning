# %%
from PIL import Image

# %%
dir_path = 'C:/Users/khanh/Downloads/src_cv/img/01'

# %%
image_path = dir_path +'/1.JPG'
print(image_path)
# Out:
# C:/Users/khanh/Downloads/src_cv/img/01/1.JPG

# %%
img01= Image.open(image_path)

# %%
img01.show()

# %%
print("Type of image: ", img01.format)
# Out:
# Type of image:  JPEG

# %%
print("Size of image: ", img01.size)
# Out:
# Size of image:  (2400, 1426)

# %%
new_img_01_path = dir_path + '/new.JPG'
new_img_png_01_path = dir_path + '/new.PNG'

img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
#img01.close()
